# %%
import cv2
import time
import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
print("Torch:", torch.__version__)

try:
    import torchvision
    print("TorchVision:", torchvision.__version__)
except Exception as e:
    print(e)
# Out:
# Torch: 2.5.1+cpu
# TorchVision: 0.20.1+cpu

# %%
IMAGE_PATH = "./dataset/robert_downey/8.jpg"

image = cv2.imread(IMAGE_PATH)
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(rgb)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1188.5), np.float64(1599.5), np.float64(-0.5))

# %%
def draw_boxes(image, boxes, color=(0,255,0), thickness=2):

    img = image.copy()

    for box in boxes:

        x1, y1, x2, y2 = map(int, box)

        cv2.rectangle(
            img,
            (x1,y1),
            (x2,y2),
            color,
            thickness
        )

    return img

# %%
haar = cv2.CascadeClassifier(
    cv2.data.haarcascades +
    "haarcascade_frontalface_default.xml"
)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

faces = haar.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5
)

print(faces)
# Out:
# [[455 476 404 404]]

# %%
result = rgb.copy()

for (x,y,w,h) in faces:

    cv2.rectangle(
        result,
        (x,y),
        (x+w,y+h),
        (0,255,0),
        4
    )

plt.imshow(result)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1188.5), np.float64(1599.5), np.float64(-0.5))

# %%
start = time.time()

faces = haar.detectMultiScale(gray)

end = time.time()

print("Inference Time:", end-start)
# Out:
# Inference Time: 0.3818070888519287

# %%
import facenet_pytorch
from facenet_pytorch import MTCNN

# %%
mtcnn = MTCNN(
    keep_all=True
)

# %%
print("Python      :", __import__("sys").version)
print("Torch       :", torch.__version__)
print("Torchvision :", torchvision.__version__)
print("NumPy       :", np.__version__)
print("FaceNet     :", facenet_pytorch.__version__)
# Out:
# Python      : 3.11.13 | packaged by Anaconda, Inc. | (main, Jun  5 2025, 13:03:15) [MSC v.1929 64 bit (AMD64)]
# Torch       : 2.5.1+cpu
# Torchvision : 0.20.1+cpu
# NumPy       : 2.4.6
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 5
#       3 print("Torchvision :", torchvision.__version__)
#       4 print("NumPy       :", np.__version__)
# ----> 5 print("FaceNet     :", facenet_pytorch.__version__)
#
# AttributeError: module 'facenet_pytorch' has no attribute '__version__'

# %%
rgb = rgb.astype(np.uint8)
boxes, probs = mtcnn.detect(rgb)

print(boxes)
print(probs)
# Out:
# [[508.9775085449219 448.1714172363281 844.1364135742188 906.98779296875]]
# [0.999933123588562]

# %%
result = draw_boxes(rgb, boxes)

plt.imshow(result)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1188.5), np.float64(1599.5), np.float64(-0.5))

# %%
start = time.time()

boxes, probs = mtcnn.detect(rgb)

end = time.time()

print(end-start)
# Out:
# 0.8974401950836182

# %%
import mediapipe as mp
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import mediapipe as mp
#
# File ~\anaconda3\envs\first\Lib\site-packages\mediapipe\__init__.py:17
#      15 from mediapipe.python import *
#      16 import mediapipe.python.solutions as solutions
# ---> 17 import mediapipe.tasks.python as tasks
#      20 del framework
#      21 del gpu
#
# File ~\anaconda3\envs\first\Lib\site-packages\mediapipe\tasks\python\__init__.py:17
#       1 # Copyright 2022 The MediaPipe Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 """MediaPipe Tasks API."""
# ---> 17 from . import audio
#      18 from . import components
#      19 from . import core
#
# ...

# %%
import os

print(os.getcwd())
print(os.listdir())

# %%
import mediapipe as mp

mp_face = mp.solutions.face_detection

detector = mp_face.FaceDetection(
    model_selection=1,
    min_detection_confidence=0.5
)

# %%
print(cv2.__version__)
print(cv2.__file__)

for name in ["CascadeClassifier", "imread", "cvtColor", "imshow", "VideoCapture"]:
    print(name, hasattr(cv2, name))
